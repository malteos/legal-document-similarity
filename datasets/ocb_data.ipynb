# %% [markdown]
# # OpenCaseBook data processing
#
# Output: meta data + gold
#
# - https://opencasebook.org/
# - https://case.law/ (Case Law Access Project; API `500 total per day`)
# -

# %%
import json
import os
import re
import time
import requests
import pickle
import pandas as pd
from pathlib import Path
from collections import defaultdict
from tqdm import tqdm_notebook as tqdm
import logging
from docsim.environment import get_env
from docsim.gold_standard import GoldStandard
from smart_open import open

logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)
# Out:
# unable to import 'smart_open.gcs', disabling that module

# %%
env = get_env()

data_dir = Path('./data/ocb')

cap_api_key = env['cap_api_key']

ocb_fp = data_dir / 'casebooks_cases_citations.json.gz'
# Out:
# /home/mostendorff/experiments/legal-docsim/environments
# Environment detected: gpu_server2 (in default.yml)

# %%
ocb = json.load(open(ocb_fp))

print(f'Loaded {len(ocb)} case books')
# Out:
# Loaded 225 case books

# %%
# Remove duplicates
def normalize_cb(url):
    # remove numbers (years, ids, ...)
    return re.sub(r'(-*)([0-9]+)(-*)', '', url)


for cb in ocb:
    norm = normalize_cb(cb['url'])
    print(norm)
# Out:
# /casebooks/landmark-decisions-right-to-an-attorney/
# /casebooks/landmark-decisions-fourth-amendment-rights/
# /casebooks/landmark-decisions-discrimination-based-on-sex/
# /casebooks/landmark-decisions-birth-control-and-abortion/
# /casebooks/administrative-law/
# /casebooks/contracts/
# /casebooks/tlc-casebook/
# /casebooks/start-up-companies-and-venture-capital/
# /casebooks/canadian-national-security-law/
# /casebooks/genetics-and-reproductive-technology-legal-ethical-issues/
# /casebooks/principles-of-insurance-law-and-regulation/
# /casebooks/regulation-of-financial-institutions-fall/
# /casebooks/an-introduction-to-the-law-of-corporations-cases-and-materials-fall/
# /casebooks/comparative-patent-law/
# /casebooks/instituciones-basicas-del-derecho-administrativo/
# /casebooks/music-digital-media-spring/
# /casebooks/copyrightx-librariessyllabus/
# /casebooks/sam-contracts-for-testing/
# /casebooks/administrative-law-forcese-university-of-ottawa-cml/
# /casebooks/modern-computation/
# /casebooks/contracts-cases-and-materials/
# /casebooks/music-digital-media-spring/
# /casebooks/music-digital-media-spring/
# /casebooks/zittrain-torts-playlist-rename/
# /casebooks/derecho-constitucional-de-puerto-rico/
# /casebooks/copyrightx-nlud/
# /casebooks/technology-human-rights-and-cybersecurity-winter/
# /casebooks/cambio-climatico-proteccion-del-medio-ambiente-y-recursos-naturales/
# /casebooks/untitled-casebook/
# /casebooks/corporations/
# /casebooks/contracts-cases-and-materials/
# /casebooks/optional-spring/
# /casebooks/bk-casebook-triantis/
# /casebooks/copyrightx-nlud-sarals-copy/
# /casebooks/completed-materials/
# /casebooks/copyright-x-ivir-simone/
# /casebooks/online-only-spring/
# /casebooks/cybersecurity-curriculum/
# /casebooks/contracts/
# /casebooks/evidence-casebook-nesson/
# /casebooks/food-safety/
# /casebooks/torts-fall-reading-group-versionwith-edits/
# /casebooks/torts-fallreading-group/
# /casebooks/critical-perspectives-on-transgender-law/
# /casebooks/con-law-ii-gowder-falluniversity-of-iowa/
# /casebooks/advanced-intellectual-property-supplemental-readings-fall/
# /casebooks/reading-group-regulating-the-blockchain/
# /casebooks/cases-cited-in-cnn-acosta-complaint-against-president-trump/
# /casebooks/torts-fall-reading-group-version/
# /casebooks/constitutional-law-separation-of-powers-federalism-and-fourteenth-amendment-spring/
# /casebooks/legislation-and-regulation/
# /casebooks/corporations/
# /casebooks/rhetoric-in-law-and-politics/
# /casebooks/constitutional-law-separation-of-powers-federalism-and-fourteenth-amendment-spring/
# /casebooks/criminal-law-springwu/
# /casebooks/lawyering-for-justice-in-the-united-states/
# /casebooks/constitutional-law/
# /casebooks/mosier-antitrust-materials-fall/
# /casebooks/fidelity-in-interpretation-spring/
# /casebooks/criminal-law-spring/
# /casebooks/karlan-torts-materials-part-i/
# /casebooks/copyright/
# /casebooks/public-international-law-forcese-university-of-ottawa/
# /casebooks/privacy-and-data-syllabus/
# /casebooks/stanford-lawcopyright-content-in-the-digital-age-spring/
# /casebooks/intermediary-liability-syllabus/
# /casebooks/topics-in-financial-regulation-consumer-and-investor-protection/
# /casebooks/copyrightx-nlud/
# /casebooks/music-digital-media-spring/
# /casebooks/rhetoric-public-discourse-spring/
# /casebooks/lahav-complex-litigation-materials/
# /casebooks/karlan-torts-materials-fall/
# /casebooks/public-law-legislation-university-of-ottawa-cml/
# /casebooks/copyrightxuct/
# /casebooks/food-law-lab/
# /casebooks/copyright-first-responders-cohortspring/
# /casebooks/fallcopyright-reading-group/
# /casebooks/copyrightx-auc-the-economics-of-copyright-and-creativity/
# /casebooks/property-supplementary-materials/
# /casebooks/internet-society-the-technologies-and-politics-of-control/
# /casebooks/music-digital-media-spring/
# /casebooks/l-introduction-to-american-law/
# /casebooks/the-anthology-of-swiss-legal-culture/
# /casebooks/the-politics-of-private-law-in-historical-and-comparative-perspective/
# /casebooks/criminal-law-spring/
# /casebooks/international-law-and-human-rights-fall/
# /casebooks/ceipi-training-seminar-intermediary-liability/
# /casebooks/topics-in-financial-regulation-consumer-and-investor-protection/
# /casebooks/music-digital-media-spring/
# /casebooks/securities-regulation-spring/
# /casebooks/copyrightx-auc-the-economics-of-copyright-and-creativity/
# /casebooks/cybersecuritythree-part-introductory-section/
# /casebooks/internet-society-the-technologies-and-politics-of-control/
# /casebooks/introduction-to-international-comparative-law-fall/
# /casebooks/administrative-law/
# /casebooks/environmental-practice-skills-methods-and-controversies-siting-and-permitting-of-a-wind-farm-as-a-case-study/
# /casebooks/federal-budget-policy-spring/
# /casebooks/copyrightx-jamaica/
# /casebooks/wipo-turin-llm-in-ip-law-copyright-module-syllabus/
# /casebooks/copyright-law-fall/
# /casebooks/copyrightx-turin-u-syllabus/
# /casebooks/criminal-law-revisions-for-future-use/
# /casebooks/an-open-internet-law-casebook/
# /casebooks/anatomy-of-a-copyright-case/
# /casebooks/criminal-law-spring/
# /casebooks/criminal-law-reading-group/
# /casebooks/controlling-cyberspace/
# /casebooks/federal-budget-policy-january/
# /casebooks/contracts/
# /casebooks/contemporary-issues-in-intelligence-gathering-spring/
# /casebooks/criminal-law-spring/
# /casebooks/torts-fall-reading-group-version/
# /casebooks/family-law-spring/
# /casebooks/conflict-of-laws-textbook/
# /casebooks/corporate-finance/
# /casebooks/federal-budget-policy-january/
# /casebooks/copyrightx-bocconi-university/
# /casebooks/criminal-law-springwu/
# /casebooks/criminal-law-spring/
# /casebooks/civil-procedure-fall/
# /casebooks/advanced-intellectual-propertycyberlaw/
# /casebooks/statutory-code-research-for-llm-students/
# /casebooks/zittrain-torts-playlist-spring/
# /casebooks/zittrain-torts-playlist-spring/
# /casebooks/sale-and-licensing-of-content-online-june/
# /casebooks/seminar-in-church-and-state/
# /casebooks/books-in-the-digital-age-a-case-study-spring/
# /casebooks/torts-springfull-version/
# /casebooks/food-law-casebook/
# /casebooks/introduction-to-the-legal-system-of-the-united-states/
# /casebooks/dan-breidenbachs-casebook/
# /casebooks/zittrain-torts-playlist-spring/
# /casebooks/copyright-fair-use-and-music-licensing-playlist/
# /casebooks/summerfirst-amendment-reading-group/
# /casebooks/copyright-first-responders-cohortspring/
# /casebooks/law-economics-and-psychology-springoren-bar-gill/
# /casebooks/property-sectionspring/
# /casebooks/federal-budget-policy/
# /casebooks/international-law-spring/
# /casebooks/death-and-dying-module-constitutional-and-statutory-rights/
# /casebooks/copyright-first-responders-cohortspring/
# /casebooks/open-source-property/
# /casebooks/corporations/
# /casebooks/asdasdasd/
# /casebooks/international-humanitarian-lawlaws-of-war/
# /casebooks/food-law-casebook-clone-test/
# /casebooks/constitutional-law-separation-of-powers-federalism-and-fourteenth-amendment-spring/
# /casebooks/contracts-griswold-reading-group/
# /casebooks/zittrain-torts-playlist-spring/
# /casebooks/advanced-legistlation-theories-of-statutory-interpretation-spring/
# /casebooks/legal-history-history-of-american-economic-regulation-spring/
# /casebooks/copyrightxuct/
# /casebooks/federal-budget-policy-january/
# /casebooks/regulation-of-financial-institutions-fall/
# /casebooks/legislation-and-regulation/
# /casebooks/constitutional-law-demo-casebook/
# /casebooks/intellectual-property-law-the-information-society/
# /casebooks/copyrightx-brasil/
# /casebooks/copyrightx-libraries-reading-list/
# /casebooks/compliance-and-computation/
# /casebooks/the-ethics-and-governance-of-artificial-intelligence/
# /casebooks/contracts-casebook-digital-version/
# /casebooks/financial-regulation-law-and-policyd-edition-foundation-pressby-michael-s-barr-howell-e-jackson-and-margaret-e-tahyar/
# /casebooks/introduction-to-international-comparative-law-fall/
# /casebooks/tclc-seminar-materials/
# /casebooks/animals-and-the-law-in-canada/
# /casebooks/university-of-geneva-internet-law-junepractising-cyberlaw-litigating-internet-disputes/
# /casebooks/regulating-online-conduct-speech-privacy-and-the-use-and-sharing-of-content-fall/
# /casebooks/introduction-to-international-comparative-law-fall/
# /casebooks/legal-classics-on-financial-regulation-fall/
# /casebooks/cost-benefit-analysis-fallspring/
# /casebooks/federal-budget-policy-january/
# /casebooks/corporations/
# /casebooks/copyright/
# /casebooks/rock-law/
# /casebooks/copyrightx-online-sections/
# /casebooks/isp-liability-bocconi-llm-of-internet-technology-syllabus/
# /casebooks/ceipi-advanced-training-on-artificial-intelligence-and-intellectual-property-syllabus/
# /casebooks/ip-intermediary-liability-and-platforms-regulation-ceipi-training-syllabus/
# /casebooks/advanced-constitutional-law/
# /casebooks/duplicate-will-delete/
# /casebooks/ceeschedule-impact-analysis-virginia-tech-spring/
# /casebooks/constitutional-law/
# /casebooks/an-introduction-to-the-law-of-corporations-cases-and-materials/
# /casebooks/first-amendment-freedom-of-expression/
# /casebooks/constitutional-law-brett/
# /casebooks/constitutional-law-separation-of-powers-federalism-and-fourteenth-amendment-spring/
# /casebooks/constitutional-law-separation-of-powers-federalism-and-fourteenth-amendment-spring/
# /casebooks/shameful-or-ignored-supreme-court-cases/
# /casebooks/reading-group-regulating-the-blockchain-v/
# /casebooks/an-introduction-to-the-law-of-corporations-cases-and-materials-fall/
# /casebooks/family-law-spring/
# /casebooks/contracts/
# /casebooks/music-digital-media-spring/
# /casebooks/constitutional-law-demo-casebook/
# /casebooks/sale-and-licensing-of-content-online-june/
# /casebooks/contracts-reading-group-for-export-only/
# /casebooks/constitutional-law-separation-of-powers-federalism-and-fourteenth-amendment-spring/
# /casebooks/zittrain-torts-playlist-spring/
# /casebooks/fin-reg-for-bug-testing-linkserror/
# /casebooks/regulating-online-conduct-speech-privacy-and-the-use-and-sharing-of-content-fall/
# /casebooks/draft-juneconstitutional-law-lessig/
# /casebooks/th-amendment-course/
# /casebooks/university-of-geneva-internet-law-junepracticing-cyberlaw-litigating-internet-disputes/
# /casebooks/ceipi-advanced-training-on-artificial-intelligence-and-intellectual-propertynd-editionsyllabus/
# /casebooks/contracts-cases-and-materials/
# /casebooks/zittrain-torts-playlist-spring/
# /casebooks/tlc-seminar-materials/
# /casebooks/comparative-copyright-law/
# /casebooks/criminal-law-springho-export-test-version/
# /casebooks/tlc-seminar-materials/
# /casebooks/copyrightx-libraries-reading-list/
# /casebooks/lawyering-for-justice-in-the-united-states-winter/
# /casebooks/lawyering-for-justice-in-the-united-states-w/
# /casebooks/internet-platforms-gdpr-and-ip-enforcement-ceipi-advanced-training/
# /casebooks/international-law-and-human-rights-fall/
# /casebooks/copyrightx-essential/
# /casebooks/financial-regulation-law-and-policyd-edition-foundation-pressby-michael-s-barr-howell-e-jackson-and-margaret-e-tahyar/
# /casebooks/financial-regulation-law-and-policy-foundation-pressby-michael-s-barr-howell-e-jackson-and-margaret-e-tahyar/
# /casebooks/conflict-of-laws-textbook/
# /casebooks/constitutional-law-separation-of-powers-federalism-and-fourteenth-amendment-spring/
# /casebooks/constitutional-law-separation-of-powers-federalism-and-fourteenth-amendment-spring/
# /casebooks/asdasdasd/
# /casebooks/food-law-casebook/
# /casebooks/financial-regulation-overview-materials/

# %%
doc_ids = set()
case_pairs = set()
case_pairs_with_label = defaultdict(list)
skipped_cbs = []
exclude_cbs = [
    'asdasdasd',
    '343-constitutional', # duplicate
    '811-constitutional-law-separation',
    '541-constitutional-',
    '752-tlc-seminar-materials',
    '464-copyrightxuct-2015',
    '246-contracts-cases-and-materials',
    '276-contracts-cases-and-materials',
    #'715-contracts-cases-and-materials',
    '651-contracts',
    'casebooks/415-contracts',
    '-will-delete',
    'test',
    '74-regulation-of-financial-institutions-fall-2015', # duplicate
    '466-regulation-of-financial-institutions-fall-2014',
    '698-draft-june-2019-constitutional-law-lessig', # draft
]

for cb in ocb:
    if len(cb['cases']) < 5:
        # Skip case books with small number of cases
        skipped_cbs.append(cb)
        continue
    
    norm = normalize_cb(cb['url'])
    
    # Check for invalid names
    skip = False
    for n in exclude_cbs:
        if n in norm or n in cb['url']:
            skipped_cbs.append(cb)
            skip = True

    if skip:
        continue
        
    print(f'{cb["url"]}: {len(cb["cases"])}')
    
    for c in cb['cases']:
        doc_ids.add(c['CAP_ID'])
        #doc_id2cb[c['CAP_ID']] = cb
        
        for cc in cb['cases']:
            if c['CAP_ID'] != cc['CAP_ID']:
                pair = (c['CAP_ID'], cc['CAP_ID'])
                case_pairs.add(pair)
                case_pairs_with_label[pair].append(cb['url'])

                
print('---')
print(f'Found {len(case_pairs):,} relevancy judgments ({len(case_pairs_with_label):,} with labels)')
print(f'Found {len(doc_ids):,} unique cases')
print(f'Found {len(ocb)} case books ({len(skipped_cbs):,} skipped or filtered)')
# Out:
# /casebooks/820-landmark-decisions-right-to-an-attorney/: 8
# /casebooks/836-landmark-decisions-fourth-amendment-rights/: 14
# /casebooks/837-landmark-decisions-discrimination-based-on-sex/: 11
# /casebooks/838-landmark-decisions-birth-control-and-abortion/: 8
# /casebooks/14-start-up-companies-and-venture-capital/: 21
# /casebooks/36-genetics-and-reproductive-technology-legal-ethical-issues/: 25
# /casebooks/39-principles-of-insurance-law-and-regulation/: 18
# /casebooks/51-an-introduction-to-the-law-of-corporations-cases-and-materials-fall-2017/: 61
# /casebooks/95-music-digital-media-spring-2018/: 30
# /casebooks/97-copyrightx-libraries-2020-syllabus/: 25
# /casebooks/151-music-digital-media-spring-2020/: 26
# /casebooks/163-music-digital-media-spring-2019/: 29
# /casebooks/185-zittrain-torts-playlist-rename/: 140
# /casebooks/195-copyrightx-nlud-2020/: 52
# /casebooks/261-corporations/: 31
# /casebooks/294-bk-casebook-triantis/: 65
# /casebooks/295-copyrightx-nlud-sarals-copy/: 51
# /casebooks/296-completed-materials/: 21
# /casebooks/297-copyright-x-ivir-simone/: 13
# /casebooks/303-contracts/: 156
# /casebooks/304-evidence-casebook-nesson/: 10
# /casebooks/316-food-safety/: 28
# /casebooks/318-torts-fall-reading-group-version-3-with-edits/: 61
# /casebooks/319-torts-fall-2015-reading-group/: 153
# /casebooks/332-con-law-ii-gowder-fall-2015-university-of-iowa/: 20
# /casebooks/333-advanced-intellectual-property-supplemental-readings-fall-2014/: 6
# /casebooks/342-torts-fall-reading-group-version-3/: 62
# /casebooks/347-legislation-and-regulation-2018/: 36
# /casebooks/357-corporations/: 31
# /casebooks/360-constitutional-law-separation-of-powers-federalism-and-fourteenth-amendment-spring-2018/: 92
# /casebooks/361-criminal-law-spring-2016-wu/: 105
# /casebooks/363-constitutional-law/: 80
# /casebooks/365-mosier-antitrust-materials-fall-2015/: 5
# /casebooks/366-fidelity-in-interpretation-spring-2016/: 85
# /casebooks/367-criminal-law-spring-2016/: 109
# /casebooks/368-karlan-torts-materials-part-i/: 86
# /casebooks/369-copyright-2016/: 46
# /casebooks/373-intermediary-liability-syllabus/: 6
# /casebooks/374-topics-in-financial-regulation-consumer-and-investor-protection/: 9
# /casebooks/375-copyrightx-nlud-2016/: 51
# /casebooks/376-music-digital-media-spring-2016/: 35
# /casebooks/378-lahav-complex-litigation-materials/: 48
# /casebooks/379-karlan-torts-materials-fall-2015/: 86
# /casebooks/381-copyrightxuct-2016/: 24
# /casebooks/382-food-law-lab/: 26
# /casebooks/383-copyright-first-responders-cohort-2-spring-2015/: 13
# /casebooks/384-fall-2013-copyright-reading-group/: 52
# /casebooks/386-property-supplementary-materials/: 6
# /casebooks/388-music-digital-media-spring-2016/: 35
# /casebooks/392-criminal-law-spring-2014/: 316
# /casebooks/393-international-law-and-human-rights-fall-2016/: 6
# /casebooks/394-ceipi-training-seminar-intermediary-liability/: 22
# /casebooks/395-topics-in-financial-regulation-consumer-and-investor-protection/: 9
# /casebooks/396-music-digital-media-spring-2015/: 35
# /casebooks/397-securities-regulation-spring-2016/: 5
# /casebooks/404-federal-budget-policy-spring-2015/: 13
# /casebooks/405-copyrightx-jamaica/: 15
# /casebooks/406-wipo-turin-llm-in-ip-law-copyright-module-syllabus/: 61
# /casebooks/407-copyrightx-turin-u-syllabus/: 62
# /casebooks/408-criminal-law-revisions-for-future-use/: 68
# /casebooks/409-an-open-internet-law-casebook/: 97
# /casebooks/410-anatomy-of-a-copyright-case/: 17
# /casebooks/411-criminal-law-spring-2017/: 117
# /casebooks/412-criminal-law-reading-group-2016/: 103
# /casebooks/414-federal-budget-policy-january-2017/: 7
# /casebooks/417-criminal-law-spring-2015/: 106
# /casebooks/419-torts-fall-reading-group-version-2/: 123
# /casebooks/420-family-law-spring-2019/: 13
# /casebooks/421-conflict-of-laws-textbook/: 213
# /casebooks/422-corporate-finance/: 5
# /casebooks/423-federal-budget-policy-january-2016/: 18
# /casebooks/424-copyrightx-bocconi-university/: 20
# /casebooks/425-criminal-law-spring-2016-wu/: 110
# /casebooks/426-criminal-law-spring-2017/: 67
# /casebooks/427-civil-procedure-fall-2014/: 101
# /casebooks/428-advanced-intellectual-propertycyberlaw/: 18
# /casebooks/430-zittrain-torts-playlist-spring-2016/: 124
# /casebooks/431-zittrain-torts-playlist-spring-2018/: 125
# /casebooks/432-sale-and-licensing-of-content-online-june-2017/: 9
# /casebooks/433-seminar-in-church-and-state/: 32
# /casebooks/435-torts-spring-2016-full-version/: 153
# /casebooks/436-food-law-casebook/: 38
# /casebooks/437-introduction-to-the-legal-system-of-the-united-states-2016/: 41
# /casebooks/438-dan-breidenbachs-casebook/: 129
# /casebooks/439-zittrain-torts-playlist-spring-2013/: 157
# /casebooks/441-summer-2016-first-amendment-reading-group/: 12
# /casebooks/442-copyright-first-responders-cohort-3-spring-2016/: 13
# /casebooks/443-law-economics-and-psychology-spring-2016-oren-bar-gill/: 5
# /casebooks/444-property-section-4-spring-2014/: 6
# /casebooks/445-federal-budget-policy/: 11
# /casebooks/446-international-law-spring-2014/: 8
# /casebooks/447-death-and-dying-module-constitutional-and-statutory-rights/: 12
# /casebooks/448-copyright-first-responders-cohort-1-spring-2014/: 13
# /casebooks/510-open-source-property/: 106
# /casebooks/451-corporations/: 30
# /casebooks/456-constitutional-law-separation-of-powers-federalism-and-fourteenth-amendment-spring-2018/: 106
# /casebooks/458-contracts-griswold-reading-group/: 92
# /casebooks/461-zittrain-torts-playlist-spring-2018/: 125
# /casebooks/462-advanced-legistlation-theories-of-statutory-interpretation-spring-2015/: 9
# /casebooks/463-legal-history-history-of-american-economic-regulation-spring-2015/: 7
# /casebooks/465-federal-budget-policy-january-2016/: 9
# /casebooks/467-legislation-and-regulation/: 77
# /casebooks/473-copyrightx-brasil-2015/: 25
# /casebooks/474-copyrightx-libraries-reading-list/: 26
# /casebooks/477-contracts-casebook-digital-version/: 160
# /casebooks/480-tclc-seminar-materials/: 16
# /casebooks/489-federal-budget-policy-january-2018/: 8
# /casebooks/490-corporations-2017/: 27
# /casebooks/493-copyright/: 51
# /casebooks/508-copyrightx-online-sections/: 26
# /casebooks/517-isp-liability-bocconi-llm-of-internet-technology-syllabus/: 8
# /casebooks/519-ip-intermediary-liability-and-platforms-regulation-ceipi-training-syllabus/: 13
# /casebooks/523-advanced-constitutional-law/: 20
# /casebooks/529-cee-5010-schedule-impact-analysis-virginia-tech-spring-2019/: 22
# /casebooks/531-constitutional-law/: 95
# /casebooks/553-an-introduction-to-the-law-of-corporations-cases-and-materials/: 48
# /casebooks/539-constitutional-law-brett/: 93
# /casebooks/542-constitutional-law-separation-of-powers-federalism-and-fourteenth-amendment-spring-2018/: 91
# /casebooks/551-shameful-or-ignored-supreme-court-cases/: 63
# /casebooks/572-an-introduction-to-the-law-of-corporations-cases-and-materials-fall-2017/: 61
# /casebooks/588-family-law-spring-2019/: 26
# /casebooks/628-contracts/: 88
# /casebooks/629-music-digital-media-spring-2019/: 29
# /casebooks/652-sale-and-licensing-of-content-online-june-2019/: 9
# /casebooks/653-contracts-reading-group-for-export-only/: 53
# /casebooks/655-constitutional-law-separation-of-powers-federalism-and-fourteenth-amendment-spring-2018/: 94
# /casebooks/664-zittrain-torts-playlist-spring-2018/: 125
# /casebooks/699-14th-amendment-course/: 33
# /casebooks/715-contracts-cases-and-materials/: 258
# /casebooks/731-zittrain-torts-playlist-spring-2018/: 125
# /casebooks/739-tlc-seminar-materials/: 16
# /casebooks/741-comparative-copyright-law/: 52
# /casebooks/754-copyrightx-libraries-reading-list-2019/: 26
# /casebooks/768-internet-platforms-gdpr-and-ip-enforcement-ceipi-advanced-training-2018/: 8
# /casebooks/773-international-law-and-human-rights-fall-2016/: 6
# /casebooks/774-copyrightx-essential/: 15
# /casebooks/808-conflict-of-laws-textbook/: 213
# /casebooks/810-constitutional-law-separation-of-powers-federalism-and-fourteenth-amendment-spring-2018/: 36
# /casebooks/813-food-law-casebook/: 45
# ---
# Found 140,256 relevancy judgments (140,256 with labels)
# Found 1,623 unique cases
# Found 225 case books (86 skipped or filtered)

# %%
'asdasdasd' in '/casebooks/asdasdasd/'
# Out:
# True

# %% [markdown]
# # Scraping missing data from CAP API

# %%
doc_id2doc = {}
doc_ids_with_error = []

# %%
with open(data_dir / 'doc_id2doc.json.gz', 'r') as f:
    doc_id2doc = json.load(f)
    
with open(data_dir / 'doc_ids_with_error.json', 'r') as f:
    doc_ids_with_error = json.load(f)

# %%
missing_doc_ids = doc_ids.difference(set(doc_id2doc.keys()))

print(f'Scraping {len(missing_doc_ids):,} missing docs')
# Out:
# Scraping 1 missing docs

# %%
for i, doc_id in enumerate(tqdm(missing_doc_ids, total=len(missing_doc_ids))):
    if doc_id in doc_ids_with_error:
        continue
        
    if doc_id in doc_id2doc:
        continue
    
    api_url = requests.get('https://api.case.law/v1/cases/4194497/')
    
    res = requests.get(
        f'https://api.case.law/v1/cases/{doc_id}/?full_case=true',
        headers={'Authorization': f'Token {cap_api_key}'}
    )
    
    if res.status_code == 200:
        doc_id2doc[doc_id] = res.json()
    else:
        logger.error(f'Error {res.status_code} at {doc_id}: {res.text}')
        doc_ids_with_error.append(doc_id)
    
    if i > 495:
        break
# Out:
# HBox(children=(IntProgress(value=0, max=41), HTML(value='')))

# %%
print(f'Scraped {len(doc_id2doc)} docs')
print(f'Scraped {len(doc_ids_with_error)} errors')
# Out:
# Scraped 1633 docs
# Scraped 1 errors

# %%
# Save results to disk

with open(data_dir / 'doc_id2doc.json', 'w') as f:
    json.dump(doc_id2doc, f)
    
with open(data_dir / 'doc_ids_with_error.json', 'w') as f:
    json.dump(doc_ids_with_error, f)
    
print(f'Saved {len(doc_id2doc)} docs')
print(f'Saved {len(doc_ids_with_error)} errors')
# Out:
# Saved 1633 docs
# Saved 1 errors

# %%
gs_df = pd.DataFrame(case_pairs, columns=[GoldStandard.seed_col, GoldStandard.target_col])
gs_df[GoldStandard.label_col] = [
    ','.join(case_pairs_with_label[tuple(p)]) for p in gs_df[[GoldStandard.seed_col, GoldStandard.target_col]].values.tolist()
]
gs_df.head()
# Out:
#     seed_id target_id                                              label
# 0   1963540   2344050                          /casebooks/628-contracts/
# 1    366591   1313660          /casebooks/427-civil-procedure-fall-2014/
# 2  11464278    890893  /casebooks/439-zittrain-torts-playlist-spring-...
# 3   3368237   2001290    /casebooks/412-criminal-law-reading-group-2016/
# 4   2255481   1310340  /casebooks/303-contracts/,/casebooks/477-contr...

# %%
gs_df.to_csv(data_dir / 'gold.csv', index=False)

# %%
from collections import defaultdict

## Texts + Meta
texts = []
doc_id2idx = {}
idx2doc_id = []

doc_id2docket_number = {}

doc_id2cit_id = defaultdict(list)
cit_id2doc_id = {}
cits = []

meta = []

for idx, (doc_id, doc) in enumerate(doc_id2doc.items()):
    if 'count' in doc:
        logger.warning(f'doc is missing data: #{doc_id} - {doc}')
        continue
        
    #title = doc['title'] if 'title' in doc else doc['name']  
    
    # Build text from title and opinions
    text = doc['name'] 
    text += '\n'    
    text += doc['casebody']['data']['head_matter']
    text += '\n'
    text += '\n\n'.join([o['text'] for o in doc['casebody']['data']['opinions']])
    
    idx2doc_id.append(doc_id)
    doc_id2idx[doc_id] = idx
    texts.append(text)
    
    doc_id2docket_number[doc_id] = doc['docket_number']
    
        
    # Extract citations + citation ids
    for _from in doc['citations']:
        # cit['type'] == 'official'
        doc_id2cit_id[doc_id].append(_from['cite'])
        
        cit_id2doc_id[_from['cite']] = doc_id
        
        for _to in doc['cites_to']:
            cits.append((_from['cite'], _to['cite']))

    # Prepare meta data
    meta_row = {
        'id': doc_id,
        'word_count': len(text.split()),
        'cites_to_count': len(doc['cites_to']),
    }
    
    for f in ['url', 'name', 'name_abbreviation', 'decision_date', 'docket_number', 'frontend_url']:
        meta_row[f] = doc[f]
               
    if len(meta_row['decision_date']) == 7:
        meta_row['decision_date'] += '-01'
    
    if len(meta_row['decision_date']) == 4:
        meta_row['decision_date'] += '-01-01'
        
    meta.append(meta_row)
# Out:
# WARNING:__main__:doc is missing data: #None - {'count': 0, 'next': None, 'previous': None, 'results': []}

# %%
# Normalize citations (replace cit ids with doc ids)
norm_cits = set()
within_corpus_cits = set()

for _from, _to in cits:
    if _from in cit_id2doc_id and _to in cit_id2doc_id:
        within_corpus_cits.add((_from, _to))

    if _from in cit_id2doc_id:
        _from = cit_id2doc_id[_from]
        
    if _to in cit_id2doc_id:
        _to = cit_id2doc_id[_to]
                
    norm_cits.add((_from, _to))

# %%
print(f'Citations in corpus {len(within_corpus_cits):,} / {len(norm_cits):,}')
# Out:
# Citations in corpus 2,836 / 70,865

# %%
# Count graph connections
doc_id2edges_count = defaultdict(int)

for _from, _to in norm_cits: 
    if _from in doc_id2idx:
        doc_id2edges_count[_from] += 1
        
    if _to in doc_id2idx:
        doc_id2edges_count[_to] += 1

# %%
meta_df = pd.DataFrame(meta)
meta_df['decision_date'] = pd.to_datetime(meta_df['decision_date'])
meta_df['decision_year'] = pd.DatetimeIndex(meta_df['decision_date']).year
meta_df['edges_count'] = [doc_id2edges_count[row['id']] for idx, row in meta_df.iterrows()]
meta_df = meta_df.set_index('id')
meta_df
# Out:
#           word_count  cites_to_count                                      url  \
# id
# 6187594         5142              23   https://api.case.law/v1/cases/6187594/
# 374589         16516              66    https://api.case.law/v1/cases/374589/
# 2350241         1624               3   https://api.case.law/v1/cases/2350241/
# 1994635         4362               6   https://api.case.law/v1/cases/1994635/
# 6130837         2892               1   https://api.case.law/v1/cases/6130837/
# ...              ...             ...                                      ...
# 3651235         4157              26   https://api.case.law/v1/cases/3651235/
# 2019891         2920              10   https://api.case.law/v1/cases/2019891/
# 3500459        57714              89   https://api.case.law/v1/cases/3500459/
# 11181745        8676              37  https://api.case.law/v1/cases/11181745/
# 9057965        16371              44   https://api.case.law/v1/cases/9057965/
#
#                                                        name  \
# id
# 6187594                     GREENE et al. v. LINDSEY et al.
# 374589    UNITED STATES v. BETHLEHEM STEEL CORPORATION e...
# 2350241   The People of the State of New York, Responden...
# 1994635   Ephraim Nute vs. Hamilton Mutual Insurance Com...
# 6130837                        UNITED STATES v. HALL et al.
# ...                                                     ...
# 3651235   OLD DOMINION COPPER MINING AND SMELTING COMPAN...
# 2019891   SECURITIES AND EXCHANGE COMMISSION, Plaintiff-...
# 3500459    HAMDAN v. RUMSFELD, SECRETARY OF DEFENSE, et al.
# 11181745                        MUSCARELLO v. UNITED STATES
# 9057965           In re EXIDE TECHNOLOGIES, et al., Debtors
#
#                                           name_abbreviation decision_date  \
# id
# 6187594                                   Greene v. Lindsey    1982-05-17
# 374589               United States v. Bethlehem Steel Corp.    1942-02-16
# 2350241                                    People v. Wesley    1990-10-23
# 1994635                   Nute v. Hamilton Mutual Insurance    1856-03-01
# 6130837                               United States v. Hall    1871-05-01
# ...                                                     ...           ...
# 3651235   Old Dominion Copper Mining & Smelting Co. v. L...    1908-05-18
# 2019891   Securities & Exchange Commission v. Guild Film...    1960-05-19
# 3500459                                  Hamdan v. Rumsfeld    2006-06-29
# 11181745                        Muscarello v. United States    1998-06-08
# 9057965                            In re Exide Technologies    2003-12-30
#
#                   docket_number                        frontend_url  \
# id
# 6187594              No. 81-341   https://cite.case.law/us/456/444/
# 374589                    No. 8   https://cite.case.law/us/315/289/
# 2350241                          https://cite.case.law/ny2d/76/555/
# 1994635                          https://cite.case.law/mass/72/174/
# 6130837                          https://cite.case.law/f-cas/26/79/
# ...                         ...                                 ...
# 3651235                 No. 206   https://cite.case.law/us/210/206/
# 2019891   No. 267, Socket 26039  https://cite.case.law/f2d/279/485/
# 3500459              No. 05-184   https://cite.case.law/us/548/557/
# 11181745            No. 96-1654   https://cite.case.law/us/524/125/
# 9057965      No. 02-11125 (KJC)    https://cite.case.law/br/303/48/
#
#           decision_year  edges_count
# id
# 6187594            1982           23
# 374589             1942           67
# 2350241            1990            3
# 1994635            1856            7
# 6130837            1871            1
# ...                 ...          ...
# 3651235            1908           26
# 2019891            1960           10
# 3500459            2006           90
# 11181745           1998           37
# 9057965            2003           45
#
# [1632 rows x 10 columns]

# %%
# Write everything to disk
meta_df.to_csv(data_dir / 'meta.csv')

# %%
json.dump(texts, open(data_dir / 'texts.json', 'w'))
json.dump(list(norm_cits), open(data_dir / 'cits.json', 'w'))
json.dump(doc_id2idx, open(data_dir / 'doc_id2idx.json', 'w'))
json.dump(idx2doc_id, open(data_dir / 'idx2doc_id.json', 'w'))

# %%
doc
# Out:
# {'id': 9057965,
#  'url': 'https://api.case.law/v1/cases/9057965/',
#  'name': 'In re EXIDE TECHNOLOGIES, et al., Debtors',
#  'name_abbreviation': 'In re Exide Technologies',
#  'decision_date': '2003-12-30',
#  'docket_number': 'No. 02-11125 (KJC)',
#  'first_page': '48',
#  'last_page': '80',
#  'citations': [{'type': 'official', 'cite': '303 B.R. 48'}],
#  'volume': {'url': 'https://api.case.law/v1/volumes/32044073261554/',
#   'volume_number': '303',
#   'barcode': '32044073261554'},
#  'reporter': {'id': 935,
#   'full_name': "West's Bankruptcy Reporter",
#   'url': 'https://api.case.law/v1/reporters/935/'},
#  'court': {'id': 9367,
#   'name_abbreviation': 'Bankr. D. Del.',
#   'slug': 'bankr-d-del',
#   'url': 'https://api.case.law/v1/courts/bankr-d-del/',
#   'name': 'United States Bankruptcy Court for the District of Delaware'},
#  'jurisdiction': {'name_long': 'United States',
#   'slug': 'us',
#   'whitelisted': False,
#   'name': 'U.S.',
#   'id': 39,
#   'url': 'https://api.case.law/v1/jurisdictions/us/'},
#  'cites_to': [{'cite': '283 F.3d 159'},
#   {'cite': '984 F.2d 1305'},
#   {'cite': '2004 at 2'},
#   {'cite': '115 F.3d 650'},
#   {'cite': '171 F.3d 249'},
#   {'cite': '146 B.R. 421'},
#   {'cite': '63 S.Ct. 727'},
#   {'cite': '264 B.R. 850'},
#   {'cite': '118 B.R. 282'},
#   {'cite': '62 B.R. 798'},
#   {'cite': '244 B.R. 705'},
#   {'cite': '85 L.Ed. 982'},
#   {'cite': '299 B.R. 732'},
#   {'cite': '844 F.2d 1142'},
#   {'cite': '137 B.R. 219'},
#   {'cite': '522 U.S. 1110'},
#   {'cite': '171 B.R. 926'},
#   {'cite': '168 B.R. 930'},
#   {'cite': '205 B.R. 625'},
#   {'cite': '330 F.3d 548'},
#   {'cite': '255 B.R. 445'},
#   {'cite': '118 S.Ct. 1039'},
#   {'cite': '87 L.Ed. 959'},
#   {'cite': '61 S.Ct. 675'},
#   {'cite': '266 B.R. 591'},
#   {'cite': '203 F.3d 203'},
#   {'cite': '79 L.Ed.2d 482'},
#   {'cite': '699 F.2d 599'},
#   {'cite': '140 F.3d 463'},
#   {'cite': '160 B.R. 941'},
#   {'cite': '465 U.S. 513'},
#   {'cite': '104 S.Ct. 1188'},
#   {'cite': '251 B.R. 213'},
#   {'cite': '228 F.3d 224'},
#   {'cite': '390 U.S. 414'},
#   {'cite': '84 B.R. 893'},
#   {'cite': '140 L.Ed.2d 105'},
#   {'cite': '88 S.Ct. 1157'},
#   {'cite': '134 F.3d 188'},
#   {'cite': '312 U.S. 510'},
#   {'cite': '318 U.S. 523'},
#   {'cite': '20 L.Ed.2d 1'},
#   {'cite': '596 F.2d 1102'},
#   {'cite': '241 B.R. 92'}],
#  'frontend_url': 'https://cite.case.law/br/303/48/',
#  'preview': [],
#  'casebody': {'data': {'opinions': [{'text': 'OPINION ON CONFIRMATION\nKEVIN J. CAREY, Bankruptcy Judge.\nThe Debtor asks that this Court confirm its Fourth Amended Joint Plan of Reorganization Under Chapter 11 of the Bankruptcy Code (the “Plan”). Objections to the Plan have been filed by various parties, including, th\'e Official Committee of Unsecured Creditors, Smith Management, LLC, HSBC Bank USA as Indenture Trustee, Enersys, Inc., and others. The hearing to consider confirmation of the Debtor’s Plan was held on October 21, 22, 25, 27, and November 1, 6, and 12, 2003. For the reasons set forth below, I conclude that the Debtor’s Plan cannot be confirmed in its present form.\nBACKGROUND\n1. The Bankruptcy Filing.\nOn April 15, 2002 (the “Petition Date”), Exide Technologies, f/k/a Exide Corporation, Exide Delaware, L.L.C., Exide Illinois and RBD Liquidation, L.L.C. (the “Original Debtors”) filed voluntary petitions for relief under chapter 11 of the Bankruptcy Code. On November 21, 2002, Dixie Metals Company and Refined Metals Corporation (the “Additional Debtors”) also filed voluntary petitions for relief under chapter 11 of the Bankruptcy Code. An order consolidating the cases for the Original Debtors and the Additional Debtors (collectively, the “Chapter 11 Cases”) was entered by the Court on November 29, 2002. The Debtor continues in possession of its properties and is operating and managing its businesses as a debtor and debtor in possession pursuant to §§ 1107(a) and 1108 of the Bankruptcy Code.\nOn April 29, 2002, the United States Trustee appointed the Official Committee of Unsecured Creditors (the “Creditors Committee”). On September 23, 2002, the Court entered an order appointing the Official Committee of Equity Security Holders of Exide Technologies (the “Equity Committee”).\n2. Summary of the Debtor’s Business,\nThe Debtor manufactures and supplies lead acid batteries for transportation and industrial applications worldwide, with operations in Europe, North America and Asia. The Debtor’s operations outside the United States are not included in the chapter 11 proceedings. The Debtor’s transportation segment represented approximately 63% of its business in fiscal year 2003. Transportation batteries include starting, lighting and ignition batteries for cars, trucks, off-road vehicles, agricultural and construction vehicles, motorcycles, recreational vehicles, boats, and other applications. In North America, Exide is the second largest manufacturer of transportation batteries. In Europe, Exide is the largest manufacturer of transportation batteries.\nThe Debtor’s industrial business consists of two segments: motive power and network power. Sales of motive power batteries represented approximately 20% of the company’s net sales for fiscal year 2003. Exide is a market leader in this segment of the worldwide industrial battery market. The largest application for motive power batteries is the materials handling industry, including forklifts, electric counter balance trucks, pedestrian pallet trucks, low level order pickers, turret trucks, tow tractors, reach trucks and very narrow aisle trucks.\nSales of network power batteries represented approximately 17% of the company’s net sales for fiscal year 2003. Network power (also known as standby or stationary) batteries are used for back-up power application to ensure continuous power supply in case of main (primary) power failure.\nOn September 29, 2000, the Debtor acquired GNB Technologies, Inc. (“GNB”), a U.S. and Pacific Rim manufacturer of both industrial and transportation batteries, from Pacific Dunlop Limited.\n3.Prepetition and DIP Lending.\nOn the Petition Date, the Debtor and certain lenders (the “DIP Lenders”) entered into the Secured Super Priority Debtor in Possession Credit Agreement (the “DIP Agreement”). Also on the Petition Date, the Debtor, its foreign non-debtor affiliates and the Prepetition Lenders executed the Standstill Agreement and Fifth Amendment  ...
#      'type': 'majority',
#      'author': 'KEVIN J. CAREY, Bankruptcy Judge.'}],
#    'head_matter': 'In re EXIDE TECHNOLOGIES, et al. , Debtors.\nNo. 02-11125 (KJC).\nUnited States Bankruptcy Court, D. Delaware.\nDec. 30, 2003.\nChristopher James Lhulier, James E. O’Neill, Kathleen Marshall DePhillips, Laura Davis Jones, Pachulski, Stang, Ziehl, Young & Jones, PC, Wilmington, DE, Matthew N. Kleiman, Yosef Riemer, Craig Primis, and Tim Elliott, Kirkland & Ellis, LLP, Chicago, IL, for Debtors.\nFrederick B. Rosner, Jaspen Schlesinger Hoffman, Wilmington, DE, Itai David Tsur, Dechert LLP, New York City, for Trustee.\nFred S. Hodara, David M. Zensky, Mitchell P. Hurley, Mary R. Masella, New York City, and Mathew S. Okin, Houston, TX, Akin Gump Strauss Hauer & Feld, L.L.P., Counsel; David B. Stratton, Stephen G. Harvey, David M. Former, Pepper Hamilton LLP, Wilmington, DE, Local Counsel; Gary Meyerhoff, Holly S. Fal-kowitz, Martin Michael, Sonnenschein Nath & Rosenthal, New York City, Special Counsel; Charlene D. Davis, The Bayard Firm, Wilmington, DE, Special Local Counsel, for the Official Committee of Unsecured Creditors for Exide Technologies, et al.\nWilliam J.F. Roll, III, Marc B. Hankin, Sherman & Sterling, LLP, New York City, and Mark D. Collins, Etta R. Wolfe, Richards, Layton & Finger, P.A., Wilmington, DE, Co-Counsel for Credit Suisse First Boston in its capacity as Administrative Agent for the Prepetition Secured Creditors.\nWilliam A. Hazeltine, Madison L. Cash-man, Potter Anderson & Corroon, LLP, Wilmington, DE, and Mark Metz, Joshua A. Blakely, Reinhart Boerner Van Deuren s.c., Milwaukee, WI, Co-Counsel for the Official Committee of Equity Security Holders.\nAndrew I. Silfen, Ronald L. Castle, Leah M. Eisenberg, Arent Fox Kintner Plotkin & Kahn, PLLC, New York City, and Michael R. Lastowski, Richard W. Riley, Duane Morris LLP, Wilmington, DE, Go-Counsel for Smith Management, LLC.\nJonathan L. Flaxer, Karel S. Karpe, Go-lenbock Eiseman Assor Bell & Peskoe LLP, New York City, Counsel for HSBC Bank USA, as Successor Indenture Trustee.\nGlenn S. Sieger, Dechert LLP, New York City, Counsel for Bank of New York as Indenture Trustee.\nMark S. Kenney, Office of the United States Trustee, Wilmington, DE.\nRobert Lapowsky, Tom Whalen, Stevens & Lee, Philadelphia, PA, Counsel for En-ersys, Inc.\nEdward S. Weisfelner, Steven B. Levine, and Scott M. Berman, Brown Rud-nick Berlack Israels LLP, New York City, William B. Bowden, Christopher Sontchi, Ashby & Geddes, Wilmington, DE, Counsel for R Investments, LDC.\n1\n. The debtors in these proceedings are: Exide Technologies, i/k/a, Exide Corporation; Exide Delaware, L.L.C.; Exide Illinois, Inc.; RBD Liquidation, L.L.C.; Dixie Metals Company; and Refined Metals Corporation (For ease of reference, the debtors shall be referred to herein as the "Debtor”).\n2\n. This Opinion constitutes the findings of fact and conclusions of law required by Fed. R.Bankr.P 7052. This Court has jurisdiction over this matter pursuant to 28 U.S.C. §§ 1334 and 157(a). This is a core proceeding pursuant to 28 U.S.C. 157(b)(1) and (b)(2)(L).',
#    'corrections': '',
#    'attorneys': ['Christopher James Lhulier, James E. O’Neill, Kathleen Marshall DePhillips, Laura Davis Jones, Pachulski, Stang, Ziehl, Young & Jones, PC, Wilmington, DE, Matthew N. Kleiman, Yosef Riemer, Craig Primis, and Tim Elliott, Kirkland & Ellis, LLP, Chicago, IL, for Debtors.',
#     'Frederick B. Rosner, Jaspen Schlesinger Hoffman, Wilmington, DE, Itai David Tsur, Dechert LLP, New York City, for Trustee.',
#     'Fred S. Hodara, David M. Zensky, Mitchell P. Hurley, Mary R. Masella, New York City, and Mathew S. Okin, Houston, TX, Akin Gump Strauss Hauer & Feld, L.L.P., Counsel; David B. Stratton, Stephen G. Harvey, David M. Former, Pepper Hamilton LLP, Wilmington, DE, Local Counsel; Gary Meyerhoff, Holly S. Fal-kowitz, Martin Michael, Sonnenschein Nath & Rosenthal, New York City, Special Counsel; Charlene D. Davis, The Bayard Firm, Wilmington, DE, Special Local Counsel, for the Official Committee of Unsecured Creditors for Exide Technologies, et al.',
#     'William J.F. Roll, III, Marc B. Hankin, Sherman & Sterling, LLP, New York City, and Mark D. Collins, Etta R. Wolfe, Richards, Layton & Finger, P.A., Wilmington, DE, Co-Counsel for Credit Suisse First Boston in its capacity as Administrative Agent for the Prepetition Secured Creditors.',
#     'William A. Hazeltine, Madison L. Cash-man, Potter Anderson & Corroon, LLP, Wilmington, DE, and Mark Metz, Joshua A. Blakely, Reinhart Boerner Van Deuren s.c., Milwaukee, WI, Co-Counsel for the Official Committee of Equity Security Holders.',
#     'Andrew I. Silfen, Ronald L. Castle, Leah M. Eisenberg, Arent Fox Kintner Plotkin & Kahn, PLLC, New York City, and Michael R. Lastowski, Richard W. Riley, Duane Morris LLP, Wilmington, DE, Go-Counsel for Smith Management, LLC.',
#     'Jonathan L. Flaxer, Karel S. Karpe, Go-lenbock Eiseman Assor Bell & Peskoe LLP, New York City, Counsel for HSBC Bank USA, as Successor Indenture Trustee.',
#     'Glenn S. Sieger, Dechert LLP, New York City, Counsel for Bank of New York as Indenture Trustee.',
#     'Mark S. Kenney, Office of the United States Trustee, Wilmington, DE.',
#     'Robert Lapowsky, Tom Whalen, Stevens & Lee, Philadelphia, PA, Counsel for En-ersys, Inc.',
#     'Edward S. Weisfelner, Steven B. Levine, and Scott M. Berman, Brown Rud-nick Berlack Israels LLP, New York City, William B. Bowden, Christopher Sontchi, Ashby & Geddes, Wilmington, DE, Counsel for R Investments, LDC.'],
#    'judges': []},
#   'status': 'ok'}}
