# %% [markdown]
# # Build gold standard from WikiSource
#
#
# Goal:
#
# ```
# category = {
#     'name_of_categoryA': [opinion_id_1, opinion_id_2, ...],
#     'name_of_categoryB': [opinion_id_1, opinion_id_2, ...],
#     }
# ```
#
# seed: opinion_id_1
# -> recommendation is relevant if `opinion_id_X` shares one of the categories of `opinion_id_1`.

# %%
import os
import numpy as np
import pandas as pd
import json
import re
import pickle
import itertools
from tqdm import tqdm

from datasets.courtlistener_data_loader import get_opinions_from_dump_dir

# %%
OUT_DIR = 'out'

# %%
# Read articles
pages = []

for fn in os.listdir(OUT_DIR):
    if fn.endswith('.json'):
        name = fn.replace('.json', '').replace('Category:', '')
        with open(os.path.join(OUT_DIR, fn)) as f:
            for page in json.load(f):
                p = {
                    'id': page['pageid'],
                    'title': page['title'],
                    'category': name,
                }
                
                if 'meta' in page:
                    p['has_meta'] = True
                    m = page['meta']
                    
                    for field in ['case no', 'casename', 'decided', 'party1', 'party2']:
                        if field in m:
                            p[field] = m[field]
                else:
                    p['has_meta'] = False
                    
                pages.append(p)
                #print(page['title'])
                #print()
                
#            break

# %%
df = pd.DataFrame(pages)

# %%
print(f'Total rows: {len(df)}')
# Out:
# Total rows: 2939

# %%
df.head()
# Out:
#        id                           title  \
# 0  704876  Ableman v. Booth (59 U.S. 479)
# 1  706392  Ableman v. Booth (62 U.S. 506)
# 2  669193       The Antelope (23 U.S. 66)
# 3  670219      The Antelope (25 U.S. 546)
# 4   26512          Dred Scott v. Sandford
#
#                                            category  has_meta  \
# 0  United States Supreme Court decisions on slavery      True
# 1  United States Supreme Court decisions on slavery      True
# 2  United States Supreme Court decisions on slavery      True
# 3  United States Supreme Court decisions on slavery      True
# 4  United States Supreme Court decisions on slavery      True
#
#                       case no                        casename        decided  \
# 0  35-In error to the supreme                Ableman v. Booth
# 1                              Ableman v. Booth (62 U.S. 506)  March 7, 1859
# 2                                                The Antelope
# 3                                                The Antelope
# 4                                                         NaN  March 6, 1857
#
#                                    party1            party2
# 0                                 Ableman             Booth
# 1                   Stephen V. R. Ableman  Sherman M. Booth
# 2  The Vice-Consuls of Spain and Portugal
# 3                            The Antelope
# 4                              Dred Scott          Sandford

# %%
 df['title'].value_counts()
# Out:
# Schechter Poultry Corporation v. United States                              6
# Marks v. United States (430 U.S. 188)                                       5
# Trinova Corporation v. Michigan Department of Treasury                      5
# Bouie v. City of Columbia                                                   5
# United States v. Verdugo-Urquidez                                           5
#                                                                            ..
# Oyama v. California                                                         1
# Florida Lime & Avocado Growers, Inc. v. Paul                                1
# Public Employees Retirement System of Ohio v. Betts/Opinion of the Court    1
# United States v. Classic                                                    1
# United States v. The Nuestra Senora De Regla                                1
# Name: title, Length: 2414, dtype: int64

# %%
 df['casename'].value_counts()
# Out:
# [[../]]                                                                                                             8
# Schechter Poultry Corporation v. United States                                                                      6
# Trinova Corporation v. Michigan Department of Treasury                                                              5
# Griffin v. County School Board of Prince Edward County                                                              4
# McKesson Corporation v. Division of Alcoholic Beverages and Tobacco Department of Business Regulation of Florida    4
#                                                                                                                    ..
# Cornell v. Green                                                                                                    1
# Fitts v. McGhee                                                                                                     1
# Federal Trade Commission v. Dean Foods Company                                                                      1
# United States v. Classic                                                                                            1
#                                                                                                                     1
# Name: casename, Length: 2051, dtype: int64

# %%
 df['has_meta'].value_counts()
# Out:
# True     2527
# False     412
# Name: has_meta, dtype: int64

# %%
df['decided'].value_counts()
# Out:
#                     1199
# March 5, 1990         13
# June 27, 1990         10
# June 21, 1990         10
# May 1, 1989           10
#                     ...
# February 2, 1903       1
# June 1, 1925           1
# Jan 7, 1935            1
# March 2, 1903          1
# March 6, 1968          1
# Name: decided, Length: 683, dtype: int64

# %%
df['category'].value_counts()[:20]
# Out:
# United States Supreme Court decisions on treaties                    318
# United States Supreme Court decisions on due process                 297
# United States Supreme Court decisions on civil rights                204
# United States Supreme Court decisions on the First Amendment         186
# United States Supreme Court decisions on securities                  177
# United States Supreme Court decisions on admiralty                   167
# United States Supreme Court decisions on the Fourteenth Amendment    155
# United States Supreme Court decisions on antitrust                   153
# United States Supreme Court decisions on civil procedure             137
# United States Supreme Court decisions on labor                       119
# United States Supreme Court decisions on evidence                    118
# United States Supreme Court original jurisdiction decisions          102
# United States Supreme Court decisions on the Fifth Amendment          92
# United States Supreme Court decisions on intellectual property        58
# United States Supreme Court decisions on federalism                   54
# United States Supreme Court decisions on the Fourth Amendment         50
# United States Supreme Court decisions on insurance                    43
# United States Supreme Court decisions on Article I                    39
# United States Supreme Court decisions on the Sixth Amendment          31
# United States Supreme Court decisions on the Commerce Clause          31
# Name: category, dtype: int64

# %% [markdown]
# # Load CL data

# %%
opinions_dump_dirs = [
    # '/Volumes/data/repo/data/courtlistener/ca1',
    '/Volumes/data/repo/data/courtlistener/scotus',
]

# %%
with open('cl_dump.pickle', 'rb') as f:
    opinions, id2oid, oid2id, texts, cits_by_source, cits_by_target, cits = pickle.load(f)

# %%
opinions = {}
id2oid = {}
oid2id = {}
cits_by_source = {}
cits_by_target = {}
cits = {}
texts = []

for dump_dir in opinions_dump_dirs:
    opinions, id2oid, oid2id, texts, cits_by_source, cits_by_target, cits = get_opinions_from_dump_dir(
        dump_dir, opinions, id2oid, oid2id, texts, cits_by_source, cits_by_target, cits, limit=0,
        extract_citations=False, text_from_html_warning=False
    )

# %%
print(f'Loaded {len(opinions)} CL opinions')
# Out:
# Loaded 64003 CL opinions

# %%
with open('cl_dump.pickle', 'wb') as f:
    pickle.dump((opinions, id2oid, oid2id, texts, cits_by_source, cits_by_target, cits), f)

# %%
opinions[2659301]
# Out:
# {'resource_uri': 'https://www.courtlistener.com:80/api/rest/v3/opinions/2659301/',
#  'id': 2659301,
#  'absolute_url': '/opinion/2659301/mccutcheon-v-federal-election-commn/',
#  'cluster': 'https://www.courtlistener.com:80/api/rest/v3/clusters/2659301/',
#  'author': None,
#  'joined_by': [],
#  'author_str': '',
#  'per_curiam': False,
#  'date_created': '2014-04-02T19:57:22.894687Z',
#  'date_modified': '2017-12-06T01:21:40.569322Z',
#  'type': '010combined',
#  'sha1': '3069dff3fe4df0da07c53d6f6a94181ddd6e9d44',
#  'page_count': 94,
#  'download_url': 'http://www.supremecourt.gov/opinions/13pdf/12-536_e1pf.pdf',
#  'local_path': 'pdf/2014/04/02/mccutcheon_v._federal_election_commn.pdf',
#  'plain_text': "(Slip Opinion)              OCTOBER TERM, 2013                                       1\n\n                                       Syllabus\n\n         NOTE: Where it is feasible, a syllabus (headnote) will be released, as is\n       being done in connection with this case, at the time the opinion is issued.\n       The syllabus constitutes no part of the opinion of the Court but has been\n       prepared by the Reporter of Decisions for the convenience of the reader.\n       See United States v. Detroit Timber & Lumber Co., 200 U. S. 321, 337.\n\n\nSUPREME COURT OF THE UNITED STATES\n\n                                       Syllabus\n\n       MCCUTCHEON ET AL. v. FEDERAL ELECTION\n\n                  COMMISSION \n\n\nAPPEAL FROM THE UNITED STATES DISTRICT COURT FOR THE\n               DISTRICT OF COLUMBIA\n\n      No. 12–536.      Argued October 8, 2013—Decided April 2, 2014\nThe right to participate in democracy through political contributions is\n  protected by the First Amendment, but that right is not absolute.\n  Congress may regulate campaign contributions to protect against\n  corruption or the appearance of corruption. See, e.g., Buckley v.\n  Valeo, 424 U. S. 1, 26–27. It may not, however, regulate contribu-\n  tions simply to reduce the amount of money in politics, or to restrict\n  the political participation of some in order to enhance the relative in-\n  fluence of others. See, e.g., Arizona Free Enterprise Club’s Freedom\n  Club PAC v. Bennett, 564 U. S. ___, ___.\n     The Federal Election Campaign Act of 1971 (FECA), as amended\n  by the Bipartisan Campaign Reform Act of 2002 (BCRA), imposes\n  two types of limits on campaign contributions. Base limits restrict\n  how much money a donor may contribute to a particular candidate or\n  committee while aggregate limits restrict how much money a donor\n  may contribute in total to all candidates or committees. 2 U. S. C.\n  §441a.\n     In the 2011–2012 election cycle, appellant McCutcheon contributed\n  to 16 different federal candidates, complying with the base limits ap-\n  plicable to each. He alleges that the aggregate limits prevented him\n  from contributing to 12 additional candidates and to a number of\n  noncandidate political committees. He also alleges that he wishes to\n  make similar contributions in the future, all within the base limits.\n  McCutcheon and appellant Republican National Committee filed a\n  complaint before a three-judge District Court, asserting that the ag-\n  gregate limits were unconstitutional under the First Amendment.\n  The District Court denied their motion for a preliminary injunction\n  and granted the Government’s motion to dismiss. Assuming that the\n\x0c2          MCCUTCHEON v. FEDERAL ELECTION COMM’N\n\n                                Syllabus\n\n    base limits appropriately served the Government’s anticorruption in-\n    terest, the District Court concluded that the aggregate limits sur-\n    vived First Amendment scrutiny because they prevented evasion of\n    the base limits.\nHeld: The judgment is reversed, and the case is remanded.\n893 F. Supp. 2d 133, reversed and remanded.\n     CHIEF JUSTICE ROBERTS, joined by JUSTICE SCALIA, JUSTICE KENNE-\n  DY, and JUSTICE ALITO, concluded that the aggregate limits are inva-\n  lid under the First Amendment. Pp. 7–40.\n     (a) Appellants’ substantial First Amendment challenge to the cur-\n  rent system of aggregate limits merits plenary consideration. Pp. 7–\n  14.\n       (1) In Buckley, this Court evaluated the constitutionality of the\n  original contribution and expenditure limits in FECA. Buckley dis-\n  tinguished the two types of limits based on the degree to which each\n  encroaches upon protected First Amendment interests. It subjected\n  expenditure limits to “the exacting scrutiny applicable to limitations\n  on core First Amendment rights of political expression.” 424 U. S., at\n  44–45. But it concluded that contribution limits impose a lesser re ...
#  'html': '',
#  'html_lawbox': '',
#  'html_columbia': None,
#  'html_with_citations': '<pre class="inline">(Slip Opinion)              OCTOBER TERM, 2013                                       1\n\n                                       Syllabus\n\n         NOTE: Where it is feasible, a syllabus (headnote) will be released, as is\n       being done in connection with this case, at the time the opinion is issued.\n       The syllabus constitutes no part of the opinion of the Court but has been\n       prepared by the Reporter of Decisions for the convenience of the reader.\n       See United States v. Detroit Timber & Lumber Co., </pre><span class="citation" data-id="96405"><a href="/opinion/96405/united-states-v-detroit-timber-lumber-co/"><span class="volume">200</span> <span class="reporter">U.S.</span> <span class="page">321</span></a></span><pre class="inline">, 337.\n\n\nSUPREME COURT OF THE UNITED STATES\n\n                                       Syllabus\n\n       MCCUTCHEON ET AL. v. FEDERAL ELECTION\n\n                  COMMISSION \n\n\nAPPEAL FROM THE UNITED STATES DISTRICT COURT FOR THE\n               DISTRICT OF COLUMBIA\n\n      No. 12–536.      Argued October 8, 2013—Decided April 2, 2014\nThe right to participate in democracy through political contributions is\n  protected by the First Amendment, but that right is not absolute.\n  Congress may regulate campaign contributions to protect against\n  corruption or the appearance of corruption. See, e.g., Buckley v.\n  Valeo, </pre><span class="citation" data-id="109380"><a href="/opinion/109380/buckley-v-valeo/"><span class="volume">424</span> <span class="reporter">U.S.</span> <span class="page">1</span></a></span><pre class="inline">, 26–27. It may not, however, regulate contribu-\n  tions simply to reduce the amount of money in politics, or to restrict\n  the political participation of some in order to enhance the relative in-\n  fluence of others. See, e.g., Arizona Free Enterprise Club’s Freedom\n  Club PAC v. Bennett, </pre><span class="citation" data-id="219735"><a href="/opinion/219735/arizona-free-enterprise-clubs-freedom-club-pac-v-bennett/"><span class="volume">564</span> <span class="reporter">U.S.</span> <span class="page"></span></a></span><pre class="inline">___, ___.\n     The Federal Election Campaign Act of 1971 (FECA), as amended\n  by the Bipartisan Campaign Reform Act of 2002 (BCRA), imposes\n  two types of limits on campaign contributions. Base limits restrict\n  how much money a donor may contribute to a particular candidate or\n  committee while aggregate limits restrict how much money a donor\n  may contribute in total to all candidates or committees. </pre><span class="citation no-link"><span class="volume">2</span> <span class="reporter">U.S.</span> <span class="page">C</span></span><pre class="inline">.\n  §441a.\n     In the 2011–2012 election cycle, appellant McCutcheon contributed\n  to 16 different federal candidates, complying with the base limits ap-\n  plicable to each. He alleges that the aggregate limits prevented him\n  from contributing to 12 additional candidates and to a number of\n  noncandidate political committees. He also alleges that he wishes to\n  make similar contributions in the future, all within the base limits.\n  McCutcheon and appellant Republican National Committee filed a\n  complaint before a three-judge District Court, asserting that the ag-\n  gregate limits were unconstitutional under the First Amendment.\n  The District Court denied their motion for a preliminary injunction\n  and granted the Government’s motion to dismiss. Assuming that the\n\x0c2          MCCUTCHEON v. FEDERAL ELECTION COMM’N\n\n                                Syllabus\n\n    base limits appropriately served the Government’s anticorruption in-\n    terest, the District Court concluded that the aggregate limits sur-\n    vived First Amendment scrutiny because they prevented evasion of\n    the base limits.\nHeld: The judgment is reversed, and the case is remanded.\n</pre><span class="citation no-link ...
#  'extracted_by_ocr': False,
#  'opinions_cited': ['https://www.courtlistener.com:80/api/rest/v3/opinions/749/',
#   'https://www.courtlistener.com:80/api/rest/v3/opinions/1741/',
#   'https://www.courtlistener.com:80/api/rest/v3/opinions/2144/',
#   'https://www.courtlistener.com:80/api/rest/v3/opinions/96405/',
#   'https://www.courtlistener.com:80/api/rest/v3/opinions/101097/',
#   'https://www.courtlistener.com:80/api/rest/v3/opinions/101741/',
#   'https://www.courtlistener.com:80/api/rest/v3/opinions/103555/',
#   'https://www.courtlistener.com:80/api/rest/v3/opinions/103870/',
#   'https://www.courtlistener.com:80/api/rest/v3/opinions/106150/',
#   'https://www.courtlistener.com:80/api/rest/v3/opinions/107841/',
#   'https://www.courtlistener.com:80/api/rest/v3/opinions/108275/',
#   'https://www.courtlistener.com:80/api/rest/v3/opinions/108360/',
#   'https://www.courtlistener.com:80/api/rest/v3/opinions/109131/',
#   'https://www.courtlistener.com:80/api/rest/v3/opinions/109296/',
#   'https://www.courtlistener.com:80/api/rest/v3/opinions/109380/',
#   'https://www.courtlistener.com:80/api/rest/v3/opinions/109638/',
#   'https://www.courtlistener.com:80/api/rest/v3/opinions/109690/',
#   'https://www.courtlistener.com:80/api/rest/v3/opinions/110551/',
#   'https://www.courtlistener.com:80/api/rest/v3/opinions/110588/',
#   'https://www.courtlistener.com:80/api/rest/v3/opinions/110644/',
#   'https://www.courtlistener.com:80/api/rest/v3/opinions/110819/',
#   'https://www.courtlistener.com:80/api/rest/v3/opinions/111370/',
#   'https://www.courtlistener.com:80/api/rest/v3/opinions/111781/',
#   'https://www.courtlistener.com:80/api/rest/v3/opinions/111782/',
#   'https://www.courtlistener.com:80/api/rest/v3/opinions/112304/',
#   'https://www.courtlistener.com:80/api/rest/v3/opinions/112319/',
#   'https://www.courtlistener.com:80/api/rest/v3/opinions/112329/',
#   'https://www.courtlistener.com:80/api/rest/v3/opinions/112596/',
#   'https://www.courtlistener.com:80/api/rest/v3/opinions/117847/',
#   'https://www.courtlistener.com:80/api/rest/v3/opinions/118057/',
#   'https://www.courtlistener.com:80/api/rest/v3/opinions/118230/',
#   'https://www.courtlistener.com:80/api/rest/v3/opinions/118335/',
#   'https://www.courtlistener.com:80/api/rest/v3/opinions/118369/',
#   'https://www.courtlistener.com:80/api/rest/v3/opinions/118382/',
#   'https://www.courtlistener.com:80/api/rest/v3/opinions/118427/',
#   'https://www.courtlistener.com:80/api/rest/v3/opinions/118456/',
#   'https://www.courtlistener.com:80/api/rest/v3/opinions/130151/',
#   'https://www.courtlistener.com:80/api/rest/v3/opinions/131149/',
#   'https://www.courtlistener.com:80/api/rest/v3/opinions/145630/',
#   'https://www.courtlistener.com:80/api/rest/v3/opinions/145706/',
#   'https://www.courtlistener.com:80/api/rest/v3/opinions/145776/',
#   'https://www.courtlistener.com:80/api/rest/v3/opinions/219735/',
#   'https://www.courtlistener.com:80/api/rest/v3/opinions/2341111/']}

# %%
opinions[87245]
# Out:
# {'resource_uri': 'https://www.courtlistener.com:80/api/rest/v3/opinions/87245/',
#  'id': 87245,
#  'absolute_url': '/opinion/87245/ableman-v-booth/',
#  'cluster': 'https://www.courtlistener.com:80/api/rest/v3/clusters/87245/',
#  'author': 'https://www.courtlistener.com:80/api/rest/v3/people/3166/',
#  'joined_by': [],
#  'author_str': '',
#  'per_curiam': False,
#  'date_created': '2010-04-28T16:01:03Z',
#  'date_modified': '2017-03-24T03:44:17.007702Z',
#  'type': '010combined',
#  'sha1': 'cbd8444ef7579929d6f8b18a75a5b6c2bb5a2c81',
#  'page_count': None,
#  'download_url': None,
#  'local_path': None,
#  'plain_text': '',
#  'html': '<p class="case_cite">62 U.S. 506</p>\n    <p class="case_cite">21 How. 506</p>\n    <p class="case_cite">16 L.Ed. 169</p>\n    <p class="parties">STEPHEN V. R. ABLEMAN, PLAINTIFF IN ERROR,<br>v.<br>SHERMAN M. BOOTH;<br>AND THE UNITED STATES, PLAINTIFF IN ERROR,<br>v.<br>SHERMAN M. BOOTH.</p>\n    <p class="date">December Term, 1858</p>\n    <div class="prelims">\n      <p class="indent">THESE two cases were brought up from the Supreme Court of the State of Wisconsin by a writ of error issued under the 25th section of the judiciary act.</p>\n      <p class="indent">The facts are stated in the opinion of the court.</p>\n      <p class="indent">They were argued by <i>Mr. Black</i> (Attorney General) for the plaintiffs in error, no counsel appearing for the defendant.</p>\n      <p class="indent">Mr. Chief Justice TANEY delivered the opinion of the court.</p>\n    </div>\n    <div class="num" id="p1">\n      <span class="num">1</span>\n      <p class="indent">The plaintiff in error in the first of these cases is the marshal of the United States for the district of Wisconsin, and the two cases have arisen out of the same transaction, and depend, to some extent, upon the same principles. On that account, they have been argued and considered together; and the following are the facts as they appear in the transcripts before us:</p>\n    </div>\n    <div class="num" id="p2">\n      <span class="num">2</span>\n      <p class="indent">Sherman M. Booth was charged before Winfield Smith, a commissioner duly appointed by the District Court of the United States for the district of Wisconsin, with having, on the 11th day of March, 1854, aided and abetted, at Milwaukee, in the said district, the escape of a fugitive slave from the deputy marshal, who had him in custody under a warrant issued by the district judge of the United States for that district, under the act of Congress of September 18, 1850.</p>\n    </div>\n    <div class="num" id="p3">\n      <span class="num">3</span>\n      <p class="indent">Upon the examination before the commissioner, he was satisfied that an offence had been committed as charged, and that there was probable cause to believe that Booth had been guilty of it; and thereupon held him to bail to appear and answer before the District Court of the United States for the district of Wisconsin, on the first Monday in July then next ensuing. But on the 26th of May his bail or surety in the recognisance delivered him to the marshal, in the presence of the commissioner, and requested the commissioner to recommit Booth to the custody of the marshal; and he having failed to recognise again for his appearance before the District Court, the commissioner committed him to the custody of the marshal, to be delivered to the keeper of the jail until he should be discharged by due course of law.</p>\n    </div>\n    <div class="num" id="p4">\n      <span class="num">4</span>\n      <p class="indent">Booth made application on the next day, the 27th of May, to A. D. Smith, one of the justices of the Supreme Court of the State of Wisconsin, for a writ of <i>habeas corpus</i>, stating that he was restrained of his liberty by Stephen V. R. Ableman, marshal of the United States for that district, under the warrant of commitment hereinbefore mentioned; and alleging that his imprisonment was illegal, because the act of Congress of September 18, 1850, was unconstitutional and void; and also that the warrant was defective, and did not describe the offence created by that act, even if the act were valid.</p>\n    </div>\n    <div class="num" id="p5">\n      <span class="num">5</span>\n      <p class="indent">Upon this application, the justice, on the same day, issued the writ of <i>habeas corpus</i>, directed to the marshal, requiring him forthwith to have the body of Booth before him, (the said justice,) together with the time and cause of his imprisonment. The marshal thereupon, on the day above mentioned, produced Booth, and made h ...
#  'html_lawbox': '<div>\n<center><b>62 U.S. 506 (1858)</b></center>\n<center><b>21 How. 506</b></center>\n<center><h1>STEPHEN V.R. ABLEMAN, PLAINTIFF IN ERROR,<br>\nv.<br>\nSHERMAN M. BOOTH AND<br>\nTHE UNITED STATES, PLAINTIFF IN ERROR,<br>\nv.<br>\nSHERMAN M. BOOTH.</h1></center>\n<center><p><b>Supreme Court of United States.</b></p></center>\n<center></center>\n<p><span class="star-pagination">*507</span> They were argued by Mr. Black (Attorney General) for the plaintiffs in error, no counsel appearing for the defendant.</p>\n<p>Mr. Chief Justice TANEY delivered the opinion of the court.</p>\n<p>The plaintiff in error in the first of these cases is the marshal of the United States for the district of Wisconsin, and the two cases have arisen out of the same transaction, and depend, to some extent, upon the same principles. On that account, they have been argued and considered together; and the following are the facts as they appear in the transcripts before us:</p>\n<p>Sherman M. Booth was charged before Winfield Smith, a commissioner duly appointed by the District Court of the United States for the district of Wisconsin, with having, on the 11th day of March, 1854, aided and abetted, at Milwaukee, in the said district, the escape of a fugitive slave from the deputy marshal, who had him in custody under a warrant issued by the district judge of the United States for that district, under the act of Congress of September 18, 1850.</p>\n<p>Upon the examination before the commissioner, he was satisfied that an offence had been committed as charged, and that there was probable cause to believe that Booth had been guilty of it; and thereupon held him to bail to appear and answer before the District Court of the United States for the district of Wisconsin, on the first Monday in July then next ensuing. But on the 26th of May his bail or surety in the recognisance delivered him to the marshal, in the presence of the commissioner, and requested the commissioner to recommit Booth to the custody of the marshal, and he having failed to recognise again for his appearance before the District Court, the commissioner committed him to the custody of the marshal, to be delivered to the keeper of the jail until he should be discharged by due course of law.</p>\n<p>Booth made application on the next day, the 27th of May, <span class="star-pagination">*508</span> to A.D. Smith, one of the justices of the Supreme Court of the State of Wisconsin, for a writ of habeas corpus, stating that he was restrained of his liberty by Stephen V.R. Ableman, marshal of the United States for that district, under the warrant of commitment hereinbefore mentioned; and alleging that his imprisonment was illegal, because the act of Congress of September 18, 1850, was unconstitutional and void; and also that the warrant was defective, and did not describe the offence created by that act, even if the act were valid.</p>\n<p>Upon this application, the justice, on the same day, issued the writ of habeas corpus, directed to the marshal, requiring him forthwith to have the body of Booth before him, (the said justice,) together with the time and cause of his imprisonment. The marshal thereupon, on the day above mentioned, produced Booth, and made his return, stating that he was received into his custody as marshal on the day before, and held in custody by virtue of the warrant of the commissioner above mentioned, a copy of which he annexed to and returned with the writ.</p>\n<p>To this return Booth demurred, as not sufficient in law to justify his detention. And upon the hearing the justice decided that his detention was illegal, and ordered the marshal to discharge him and set him at liberty, which was accordingly done.</p>\n<p>Afterwards, on the 9th of June, in the same year, the marshal applied to the Supreme Court of the State for a certiorari, setting forth in his application the proceedings hereinbefore mentioned, and charging that the release of Booth by the justice w ...
#  'html_columbia': None,
#  'html_with_citations': '<div>\n<center><b><span class="citation no-link"><span class="volume">62</span> <span class="reporter">U.S.</span> <span class="page">506</span></span> (1858)</b></center>\n<center><b><span class="citation no-link"><span class="volume">21</span> <span class="reporter">How.</span> <span class="page">506</span></span></b></center>\n<center><h1>STEPHEN V.R. ABLEMAN, PLAINTIFF IN ERROR,<br>\nv.<br>\nSHERMAN M. BOOTH AND<br>\nTHE UNITED STATES, PLAINTIFF IN ERROR,<br>\nv.<br>\nSHERMAN M. BOOTH.</h1></center>\n<center><p><b>Supreme Court of United States.</b></p></center>\n<center></center>\n<p><span class="star-pagination">*507</span> They were argued by Mr. Black (Attorney General) for the plaintiffs in error, no counsel appearing for the defendant.</p>\n<p>Mr. Chief Justice TANEY delivered the opinion of the court.</p>\n<p>The plaintiff in error in the first of these cases is the marshal of the United States for the district of Wisconsin, and the two cases have arisen out of the same transaction, and depend, to some extent, upon the same principles. On that account, they have been argued and considered together; and the following are the facts as they appear in the transcripts before us:</p>\n<p>Sherman M. Booth was charged before Winfield Smith, a commissioner duly appointed by the District Court of the United States for the district of Wisconsin, with having, on the 11th day of March, 1854, aided and abetted, at Milwaukee, in the said district, the escape of a fugitive slave from the deputy marshal, who had him in custody under a warrant issued by the district judge of the United States for that district, under the act of Congress of September 18, 1850.</p>\n<p>Upon the examination before the commissioner, he was satisfied that an offence had been committed as charged, and that there was probable cause to believe that Booth had been guilty of it; and thereupon held him to bail to appear and answer before the District Court of the United States for the district of Wisconsin, on the first Monday in July then next ensuing. But on the 26th of May his bail or surety in the recognisance delivered him to the marshal, in the presence of the commissioner, and requested the commissioner to recommit Booth to the custody of the marshal, and he having failed to recognise again for his appearance before the District Court, the commissioner committed him to the custody of the marshal, to be delivered to the keeper of the jail until he should be discharged by due course of law.</p>\n<p>Booth made application on the next day, the 27th of May, <span class="star-pagination">*508</span> to A.D. Smith, one of the justices of the Supreme Court of the State of Wisconsin, for a writ of habeas corpus, stating that he was restrained of his liberty by Stephen V.R. Ableman, marshal of the United States for that district, under the warrant of commitment hereinbefore mentioned; and alleging that his imprisonment was illegal, because the act of Congress of September 18, 1850, was unconstitutional and void; and also that the warrant was defective, and did not describe the offence created by that act, even if the act were valid.</p>\n<p>Upon this application, the justice, on the same day, issued the writ of habeas corpus, directed to the marshal, requiring him forthwith to have the body of Booth before him, (the said justice,) together with the time and cause of his imprisonment. The marshal thereupon, on the day above mentioned, produced Booth, and made his return, stating that he was received into his custody as marshal on the day before, and held in custody by virtue of the warrant of the commissioner above mentioned, a copy of which he annexed to and returned with the writ.</p>\n<p>To this return Booth demurred, as not sufficient in law to justify his detention. And upon the hearing the justice decided that his detention was illegal, and ordered the marshal to discharge him and set him at liberty, which was accordingly done.</p>\n< ...
#  'extracted_by_ocr': False,
#  'opinions_cited': []}

# %%
a = df.iloc[1, :]
a
# Out:
# id                                                    706392
# title                         Ableman v. Booth (62 U.S. 506)
# category    United States Supreme Court decisions on slavery
# has_meta                                                True
# case no
# casename                      Ableman v. Booth (62 U.S. 506)
# decided                                        March 7, 1859
# party1                                 Stephen V. R. Ableman
# party2                                      Sherman M. Booth
# Name: 1, dtype: object

# %%
match = opinions[87245]
match.keys()
# Out:
# dict_keys(['resource_uri', 'id', 'absolute_url', 'cluster', 'author', 'joined_by', 'author_str', 'per_curiam', 'date_created', 'date_modified', 'type', 'sha1', 'page_count', 'download_url', 'local_path', 'plain_text', 'html', 'html_lawbox', 'html_columbia', 'html_with_citations', 'extracted_by_ocr', 'opinions_cited'])

# %%
opinions[87245]['html']
# Out:
# '<p class="case_cite">62 U.S. 506</p>\n    <p class="case_cite">21 How. 506</p>\n    <p class="case_cite">16 L.Ed. 169</p>\n    <p class="parties">STEPHEN V. R. ABLEMAN, PLAINTIFF IN ERROR,<br>v.<br>SHERMAN M. BOOTH;<br>AND THE UNITED STATES, PLAINTIFF IN ERROR,<br>v.<br>SHERMAN M. BOOTH.</p>\n    <p class="date">December Term, 1858</p>\n    <div class="prelims">\n      <p class="indent">THESE two cases were brought up from the Supreme Court of the State of Wisconsin by a writ of error issued under the 25th section of the judiciary act.</p>\n      <p class="indent">The facts are stated in the opinion of the court.</p>\n      <p class="indent">They were argued by <i>Mr. Black</i> (Attorney General) for the plaintiffs in error, no counsel appearing for the defendant.</p>\n      <p class="indent">Mr. Chief Justice TANEY delivered the opinion of the court.</p>\n    </div>\n    <div class="num" id="p1">\n      <span class="num">1</span>\n      <p class="indent">The plaintiff in error in the first of these cases is the marshal of the United States for the district of Wisconsin, and the two cases have arisen out of the same transaction, and depend, to some extent, upon the same principles. On that account, they have been argued and considered together; and the following are the facts as they appear in the transcripts before us:</p>\n    </div>\n    <div class="num" id="p2">\n      <span class="num">2</span>\n      <p class="indent">Sherman M. Booth was charged before Winfield Smith, a commissioner duly appointed by the District Court of the United States for the district of Wisconsin, with having, on the 11th day of March, 1854, aided and abetted, at Milwaukee, in the said district, the escape of a fugitive slave from the deputy marshal, who had him in custody under a warrant issued by the district judge of the United States for that district, under the act of Congress of September 18, 1850.</p>\n    </div>\n    <div class="num" id="p3">\n      <span class="num">3</span>\n      <p class="indent">Upon the examination before the commissioner, he was satisfied that an offence had been committed as charged, and that there was probable cause to believe that Booth had been guilty of it; and thereupon held him to bail to appear and answer before the District Court of the United States for the district of Wisconsin, on the first Monday in July then next ensuing. But on the 26th of May his bail or surety in the recognisance delivered him to the marshal, in the presence of the commissioner, and requested the commissioner to recommit Booth to the custody of the marshal; and he having failed to recognise again for his appearance before the District Court, the commissioner committed him to the custody of the marshal, to be delivered to the keeper of the jail until he should be discharged by due course of law.</p>\n    </div>\n    <div class="num" id="p4">\n      <span class="num">4</span>\n      <p class="indent">Booth made application on the next day, the 27th of May, to A. D. Smith, one of the justices of the Supreme Court of the State of Wisconsin, for a writ of <i>habeas corpus</i>, stating that he was restrained of his liberty by Stephen V. R. Ableman, marshal of the United States for that district, under the warrant of commitment hereinbefore mentioned; and alleging that his imprisonment was illegal, because the act of Congress of September 18, 1850, was unconstitutional and void; and also that the warrant was defective, and did not describe the offence created by that act, even if the act were valid.</p>\n    </div>\n    <div class="num" id="p5">\n      <span class="num">5</span>\n      <p class="indent">Upon this application, the justice, on the same day, issued the writ of <i>habeas corpus</i>, directed to the marshal, requiring him forthwith to have the body of Booth before him, (the said justice,) together with the time and cause of his imprisonment. The marshal thereupon, on the day above mentioned, produced Booth, and made his return ...

# %% [markdown]
# # Find matching CL opinions (try differnt slugs)

# %%
def casename_to_slug(casename):
    # casename)
    return re.sub('[^0-9a-zA-Z\s]+', '-', re.sub(r'\((.*?)\)', '', casename))\
        .lower()\
        .replace('.', '-')\
        .replace(' ', '-').replace('--', '-').strip('-')

def slug_from_opinion(opinion):
    match = re.search(r'\/([0-9]+)\/([a-z-]+)', opinion['absolute_url'])
    
    if match:
        return match.group(2)
    else:
        return

# %%
slug2oid = {}
slug_duplicates = set()

for oid, opinion in opinions.items():
    slug = slug_from_opinion(opinion)
    
    if slug:
        if slug in slug2oid:
            slug_duplicates.add(slug)
        slug2oid[slug] = oid
        
print(f'slug_duplicates = {len(slug_duplicates)} / {len(opinions)}')
# Out:
# slug_duplicates = 4810 / 64003

# %%
df['oid'] = ''

# %%
df['found'] = 0
df['oid'] = ''

not_found_idxs = set()

found = 0
found_duplicates = 0

for idx, row in df.iterrows(): # tqdm(df.iterrows())
    row2oid(idx)

# %% [markdown]
# ```
# # simple
# found = 1431 / 2939
# found_duplicates = 301 / 2939
# not found with slug = 997
# ##
# found = 1574 / 2939
# found_duplicates = 311 / 2939
# not found with slug = 997
# ##
# found = 1589 / 2939
# found_duplicates = 313 / 2939
# not found with slug = 983
# ## combinations
# found = 1993 / 2939 (67.81%)
# found_duplicates = 374 / 2939
# not found with slug = 1143
# ```

# %%
print(f'found = {found} / {len(df)} ({round(found/len(df), 4)*100}%)')
print(f'found_duplicates = {found_duplicates} / {len(df)}')
print(f'not found with slug = {len(not_found_idxs)}')
# Out:
# found = 1993 / 2939 (67.81%)
# found_duplicates = 374 / 2939
# not found with slug = 1143

# %%
# Categories for that we have the corresponding CL opinion
df[df['found'] > 0]['category'].value_counts()[:20]
# Out:
# United States Supreme Court decisions on treaties                    230
# United States Supreme Court decisions on due process                 195
# United States Supreme Court decisions on admiralty                   147
# United States Supreme Court decisions on securities                  145
# United States Supreme Court decisions on the First Amendment         121
# United States Supreme Court decisions on antitrust                   116
# United States Supreme Court decisions on the Fourteenth Amendment    114
# United States Supreme Court decisions on civil rights                 95
# United States Supreme Court original jurisdiction decisions           91
# United States Supreme Court decisions on evidence                     90
# United States Supreme Court decisions on civil procedure              90
# United States Supreme Court decisions on the Fifth Amendment          75
# United States Supreme Court decisions on the Fourth Amendment         40
# United States Supreme Court decisions on intellectual property        38
# United States Supreme Court decisions on federalism                   34
# United States Supreme Court decisions on the Sixth Amendment          27
# United States Supreme Court decisions on the Eighth Amendment         27
# United States Supreme Court decisions on insurance                    27
# United States Supreme Court decisions on Article I                    24
# United States Supreme Court decisions on criminal law                 19
# Name: category, dtype: int64

# %%
df['found'].value_counts()[:20]
# Out:
# 1    1993
# 0     946
# Name: found, dtype: int64

# %%
"""
partial party names
Bank v. Sherman Hickling => Bank v. Sherman
Bass Ratcliff Gretton v. State Tax Commission => BASS, ETC., LTD. v. Tax Comm
"""

combs = []    
query_operators = [
    #'A', 'B', 'C', 'D'
    lambda x: x,
    lambda x: x.replace('company', 'co'),
    lambda x: x.replace('-c-', '-co-'),        
    lambda x: x.replace('corporation', 'corp'),
    lambda x: x.replace('city-of-', ''),
    lambda x: x.replace('insurance', 'ins'),  
    lambda x: x.replace('vermont', 'vt'),
    lambda x: x.replace('-southern-california-gas-co', ''),
    lambda x: x.replace('-inv-', '-investment-'),
    lambda x: x.replace('administrator-of-', ''),
    lambda x: x.replace('--', '-'),      
    lambda x: x.replace('base-ball', 'baseball'),
    #lambda x: x.replace('-v-', '-inc-v-'),
    lambda x: x.replace('federal-trade-commission', 'ftc'),
    #lambda x: x[:72],
    lambda x: x.replace('-railway-co', '-r-co'),
    lambda x: x.replace('-railroad-co', '-r-co'),
    lambda x: x.replace('-texas', '-tex'),
]

for i, op in enumerate(query_operators):
    combs.append([op])
    els = [list(x) for x in itertools.combinations(query_operators, i)]
    combs.extend(els)

def get_queries(slug, combs):
    queries = set()

    for comb in combs:
        if len(comb) > 0:
            comb_q = slug
            for operator in comb:
                comb_q = operator(comb_q)
            queries.add(comb_q)
    return queries


def row2oid(idx, debug=False):
    global slug2oid, slug_duplicates, not_found_idxs, found, found_duplicates, df
    row = df.iloc[idx, :]
    
    if isinstance(row['casename'], str):
        slug = casename_to_slug(row['casename'])
    else:
        slug = casename_to_slug(row['title'])

    queries = get_queries(slug, combs)

    if debug:
        print(f'Queries: {queries}')
    for query in queries:        
        if query in slug2oid:
            found += 1
            oid = str(slug2oid[query])
            
            if df.at[idx, 'found'] == 0:  # already found
                df.at[idx, 'oid'] = oid
            else:                
                df.at[idx, 'oid'] += ',' + oid
                
            df.at[idx, 'found'] += 1
            
            if debug:
                print('Found!')
            if query in slug_duplicates:
                found_duplicates += 1
                if debug:
                    print('--- duplicate')
            return True
        else:
            not_found_idxs.add(idx)
    return False


idx = 2911
row = df.iloc[idx, :]

print(row.values)

row2oid(idx, True)
# Out:
# [890328 'United States v. Carolene Products Company'
#  'United States Supreme Court decisions on the Commerce Clause' True ''
#  'United States v. Carolene Products Company' 'April 25, 1938'
#  'United States' 'Carolene Products Company' 0 '']
# Queries: {'united-states-v-carolene-products-company', 'united-states-v-carolene-products-co'}
# Found!
# True

# %%
# Gold labels without CL opinion
df[df['found'] == 0]
# Out:
#           id                                              title  \
# 11    746419                           Bank v. Sherman Hickling
# 12    870807      Bass Ratcliff Gretton v. State Tax Commission
# 14    862426                      Birge-Forbers Company v. Heye
# 32    850570  Continental Commercial Trust Savings Bank v. C...
# 33    752501                       County of Sherman v. Simonds
# ...      ...                                                ...
# 2934  870285  United States v. Ninety-Five Barrels Alleged A...
# 2935  884631                         Burroughs v. United States
# 2936  874266               Myers v. United States (272 U.S. 52)
# 2937   82891                                        Prize Cases
# 2938  907631  Youngstown Sheet & Tube Company v. Sawyer (343...
#
#                                                category  has_meta case no  \
# 11    United States Supreme Court decisions on antit...      True
# 12    United States Supreme Court decisions on antit...      True
# 14    United States Supreme Court decisions on antit...      True
# 32    United States Supreme Court decisions on antit...     False     NaN
# 33    United States Supreme Court decisions on antit...      True
# ...                                                 ...       ...     ...
# 2934  United States Supreme Court decisions on statu...      True
# 2935  United States Supreme Court decisions on Artic...      True
# 2936  United States Supreme Court decisions on Artic...      True
# 2937  United States Supreme Court decisions on Artic...      True     NaN
# 2938  United States Supreme Court decisions on Artic...     False     NaN
#
#                                                casename  \
# 11                             Bank v. Sherman Hickling
# 12        Bass Ratcliff Gretton v. State Tax Commission
# 14                        Birge-Forbers Company v. Heye
# 32                                                  NaN
# 33                         County of Sherman v. Simonds
# ...                                                 ...
# 2934  United States v. Ninety-Five Barrels Alleged A...
# 2935                         Burroughs v. United States
# 2936               Myers v. United States (272 U.S. 52)
# 2937                                                NaN
# 2938                                                NaN
#
#                                                 decided  \
# 11
# 12                                         Nov 17, 1924
# 14                                         Jan 12, 1920
# 32                                                  NaN
# 33    by the commissioners of Sherman county, in the...
# ...                                                 ...
# 2934                                       June 2, 1924
# 2935                                        Jan 8, 1934
# 2936                                       Oct 25, 1926
# 2937                                                NaN
# 2938                                                NaN
#
#                      party1                                           party2  \
# 11                     Bank                                 Sherman Hickling
# 12    Bass Ratcliff Gretton                             State Tax Commission
# 14    Birge-Forbers Company                                             Heye
# 32                      NaN                                              NaN
# 33        County of Sherman                                          Simonds
# ...                     ...                                              ...
# 2934          United States  Ninety-Five Barrels Alleged Apple Cider Vinegar
# 2935              Burroughs                                    United States
# 2936                  Myers                      United States (272 U.S. 52)
# 2937                    NaN                                              NaN
# 2938                    NaN                                              NaN
#
#       found oid
# 11        0
# 12        0
# 14        0
# 32        0
# 33        0
# ...     ...  ..
# 2934      0
# 2935      0
# 2936      0
# 2937      0
# 2938      0
#
# [2861 rows x 11 columns]

# %%
df['oid'].value_counts()
# Out:
#           946
# 99838      14
# 103388      9
# 97980       8
# 105335      5
#          ...
# 88917       1
# 106660      1
# 112308      1
# 112603      1
# 108274      1
# Name: oid, Length: 1547, dtype: int64

# %%
df[df['oid'] == '99838']
# Out:
#           id                             title  \
# 2654  862994  Oklahoma v. Texas (252 U.S. 372)
# 2655  863723  Oklahoma v. Texas (253 U.S. 465)
# 2656  864019  Oklahoma v. Texas (254 U.S. 280)
# 2657  865594  Oklahoma v. Texas (256 U.S. 602)
# 2658  865178   Oklahoma v. Texas (256 U.S. 70)
# 2659  866112  Oklahoma v. Texas (257 U.S. 616)
# 2660  866650  Oklahoma v. Texas (258 U.S. 574)
# 2661  866970  Oklahoma v. Texas (259 U.S. 565)
# 2662  867535  Oklahoma v. Texas (260 U.S. 606)
# 2663  867915  Oklahoma v. Texas (261 U.S. 340)
# 2664  867921  Oklahoma v. Texas (261 U.S. 345)
# 2665  868638  Oklahoma v. Texas (262 U.S. 505)
# 2666  868734  Oklahoma v. Texas (262 U.S. 724)
# 2667  869987   Oklahoma v. Texas (265 U.S. 76)
#
#                                                category  has_meta case no  \
# 2654  United States Supreme Court original jurisdict...      True
# 2655  United States Supreme Court original jurisdict...      True
# 2656  United States Supreme Court original jurisdict...      True
# 2657  United States Supreme Court original jurisdict...      True
# 2658  United States Supreme Court original jurisdict...      True
# 2659  United States Supreme Court original jurisdict...      True
# 2660  United States Supreme Court original jurisdict...      True
# 2661  United States Supreme Court original jurisdict...      True
# 2662  United States Supreme Court original jurisdict...      True
# 2663  United States Supreme Court original jurisdict...      True
# 2664  United States Supreme Court original jurisdict...      True
# 2665  United States Supreme Court original jurisdict...      True
# 2666  United States Supreme Court original jurisdict...      True
# 2667  United States Supreme Court original jurisdict...      True
#
#                               casename         decided    party1  \
# 2654                 Oklahoma v. Texas                  Oklahoma
# 2655  Oklahoma v. Texas (253 U.S. 465)                  Oklahoma
# 2656  Oklahoma v. Texas (254 U.S. 280)                  Oklahoma
# 2657  Oklahoma v. Texas (256 U.S. 602)                  Oklahoma
# 2658   Oklahoma v. Texas (256 U.S. 70)  April 11, 1921  Oklahoma
# 2659  Oklahoma v. Texas (257 U.S. 616)                  Oklahoma
# 2660  Oklahoma v. Texas (258 U.S. 574)     May 1, 1922  Oklahoma
# 2661  Oklahoma v. Texas (259 U.S. 565)                  Oklahoma
# 2662  Oklahoma v. Texas (260 U.S. 606)    Jan 15, 1923  Oklahoma
# 2663  Oklahoma v. Texas (261 U.S. 340)                  Oklahoma
# 2664  Oklahoma v. Texas (261 U.S. 345)                  Oklahoma
# 2665  Oklahoma v. Texas (262 U.S. 505)                  Oklahoma
# 2666  Oklahoma v. Texas (262 U.S. 724)                  Oklahoma
# 2667   Oklahoma v. Texas (265 U.S. 76)                  Oklahoma
#
#                     party2  found    oid
# 2654                 Texas      1  99838
# 2655                 Texas      1  99838
# 2656                 Texas      1  99838
# 2657  Texas (256 U.S. 602)      1  99838
# 2658   Texas (256 U.S. 70)      1  99838
# 2659  Texas (257 U.S. 616)      1  99838
# 2660  Texas (258 U.S. 574)      1  99838
# 2661  Texas (259 U.S. 565)      1  99838
# 2662  Texas (260 U.S. 606)      1  99838
# 2663  Texas (261 U.S. 340)      1  99838
# 2664  Texas (261 U.S. 345)      1  99838
# 2665  Texas (262 U.S. 505)      1  99838
# 2666  Texas (262 U.S. 724)      1  99838
# 2667   Texas (265 U.S. 76)      1  99838

# %% [markdown]
# # Build gold df
#
# All oids that belong to the same group
#
# Category => OIDs
# ```json
# {
#     "Category XY": [1, 2, 3]
# }
# ```
#
# OID => OIDs
# ```json
# {
#     1: [2, 3],
#     2: [1, 3],
#     3: [2, 1],
#
# }
# ```

# %%
# categories with more than 20 matching oids
cats = df[df['found'] > 0]['category'].value_counts() #[:20]
cats = list(cats.keys())

# %%
# Find oids for each category
cat2oids = {}
oid2relevant_oids = {}

for cat in cats:
    oids = list(set(df[(df['category'] == cat) & (df['found'] > 0)]['oid'].values)) # TODO maybe convert to int
    oids = [int(i) for i in oids]
    cat2oids[cat] = oids
    
    for oid in oids:
        # every other id except current id
        relevant_oids = oids.copy()
        relevant_oids.remove(oid)
        
        if oid in oid2relevant_oids:
            oid2relevant_oids[oid] += relevant_oids
        else:
            oid2relevant_oids[oid] = relevant_oids
        
    
len(cat2oids)
# Out:
# 64

# %%
with open('cat2oids.pickle', 'wb') as f:
    pickle.dump(cat2oids, f)
    
with open('cat2oids.json', 'w') as f:
    json.dump(cat2oids, f)
    
with open('wikisource_oid2relevant_oids.pickle', 'wb') as f:
    pickle.dump(oid2relevant_oids, f)
    
with open('wikisource_oid2relevant_oids.json', 'w') as f:
    json.dump(oid2relevant_oids, f)
